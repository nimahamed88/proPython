# %%
import numpy as np
from numpy import random

x = random.randint(100)

print(x)
# Out:
# 24

# %%
x = random.rand()

print(x)
# Out:
# 0.09332504817640874

# %%
x=random.randint(100, size=(5))

print(x)
# Out:
# [30 48 50 42 36]
# <class 'numpy.ndarray'>

# %%
x = random.randint(100, size=(3, 5))

print(x)
# Out:
# [[64  6 57 53 86]
#  [45 35 32 42 30]
#  [14  4 47 27 84]]

# %%
x = random.rand(5)

print(x)
# Out:
# [0.13972711 0.54177069 0.15394549 0.48399526 0.12088325]

# %%
x = random.rand(3, 5)

print(x)
# Out:
# [[0.19511486 0.83786199 0.95336157 0.24786575 0.73714529]
#  [0.46885573 0.16265539 0.527043   0.0864413  0.43456589]
#  [0.37277216 0.62656168 0.35936039 0.48208768 0.03534896]]

# %%
arr= [1,2,3,4,5,6]

# %%
x = random.choice(arr)
print(x)
# Out:
# 4

# %%
x = random.choice([3, 5, 7, 9], size=(3))

print(x)
# Out:
# [5 9 5]

# %%
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(5))

print(x)
# Out:
# [3 7 7 7 7]

# %%
arr = [1,2,3,4,5,6]
p = [0.1 , 0.2 , 0.3 , 0.4 , 0 , 0]

x = random.choice(arr, p=p , size=(5,5))
print(x)
# Out:
# [[2 4 4 4 4]
#  [3 4 3 4 3]
#  [1 1 4 4 2]
#  [3 2 2 2 3]
#  [4 4 3 3 4]]

# %%
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5))

print(x)
# Out:
# [[5 7 5 7 7]
#  [7 5 7 7 5]
#  [7 7 3 7 7]]

# %%
arr = np.array([1, 2, 3, 4, 5])

random.shuffle(arr)

print(arr)
# Out:
# [4 5 1 3 2]

# %%
#The permutation() method returns a re-arranged array (and leaves the original array un-changed).


arr = np.array([1, 2, 3, 4, 5])

print(random.permutation(arr))
# Out:
# [2 1 5 4 3]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot([0, 1, 2, 3, 4, 5 , 6 , 7])

plt.show()
# Out:
# /tmp/ipykernel_53002/508732453.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5 , 6 , 7])

# %%
sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

plt.show()
# Out:
# /tmp/ipykernel_53002/1097224426.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

# %%
x = random.normal(size=(2,3))
x
# Out:
# array([[ 0.23628729,  0.24693219,  0.81958917],
#        [ 0.09543617, -0.64896856,  0.6208452 ]])

# %%
x = random.normal(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[ 0.477583    3.57413662  2.58826275]
#  [-1.04449646  3.65670343  2.048801  ]]

# %%
sns.distplot(random.normal(size=1000), hist=False)

plt.show()
# Out:
# /tmp/ipykernel_53002/4119326688.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=False)

# %%
x = random.binomial(n=10, p=0.5, size=10)

print(x)
# Out:
# [7 6 6 5 6 8 3 6 4 7]

# %%
import numpy as np
# from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns


sns.distplot(random.binomial(n = 10 , p = 0.5 , size=10000) , hist = True )
plt.show()
# Out:
# /tmp/ipykernel_53002/447541844.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n = 10 , p = 0.5 , size=10000) , hist = True )

# %%
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(10))

print(x)
# Out:
# [5 7 5 3 5 7 7 7 3 7]

# %%
x = random.normal(loc=1, scale=1, size=(2, 3))

print(x)
# Out:
# [[ 2.08255202 -0.51273901  1.34934952]
#  [-0.15863203 -0.37796874  0.98803641]]

# %%
sns.distplot(random.normal(loc = 1 , scale=0.5, size=(2000)))
plt.show()
# Out:
# /tmp/ipykernel_53002/1149694992.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc = 1 , scale=0.5, size=(2000)))

# %%
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True)
plt.show()
# Out:
# /tmp/ipykernel_53002/2815019055.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True)

# %%
sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')
sns.distplot(random.poisson(lam=50, size=1000), hist=False, label='poisson')


plt.show()
# Out:
# /tmp/ipykernel_53002/1106829846.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
# /tmp/ipykernel_53002/1106829846.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.distplot(random.uniform(a=1,b =10,size=1000), hist=False)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 sns.distplot(random.uniform(a=1,b =10,size=1000), hist=False)
#       3 plt.show()
#
# File mtrand.pyx:1014, in numpy.random.mtrand.RandomState.uniform()
#
# TypeError: uniform() got an unexpected keyword argument 'a'

# %%
sns.distplot(random.uniform(1,10,size=1000))

plt.show()
# Out:
# /tmp/ipykernel_53002/2338315770.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(1,10,size=1000))

# %%
x = random.logistic(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[ 0.11462388 -3.42882426 -1.42174137]
#  [-1.97843675  4.2175073   5.66556845]]

# %%
sns.distplot(random.logistic(size=1000), hist=False)

plt.show()
# Out:
# /tmp/ipykernel_53002/3861040944.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(size=1000), hist=False)

# %%
sns.distplot(random.chisquare(df=15, size=1000), hist=False)

plt.show()
# Out:
# /tmp/ipykernel_53002/2527944927.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.chisquare(df=15, size=1000), hist=False)
